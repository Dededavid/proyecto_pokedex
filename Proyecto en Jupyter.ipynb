# %%
import pandas as pd

# %%
df = pd.read_csv(('./input/Pokemon.csv'), encoding = 'ISO-8859-1')
df
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
#quiero sacar la primera generación de Pokémon

filter1 = df['Generation'] == 1
df_pk_one = df[filter1]
df_pk_one
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass    Poison    318   45      49
# 1      2                    Ivysaur     Grass    Poison    405   60      62
# 2      3                   Venusaur     Grass    Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 4      4                 Charmander      Fire       NaN    309   39      52
# 5      5                 Charmeleon      Fire       NaN    405   58      64
# 6      6                  Charizard      Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 9      7                   Squirtle     Water       NaN    314   44      48
# 10     8                  Wartortle     Water       NaN    405   59      63
# ...

# %%
#eliminando Pokémon Mega

df_mega=df_pk_one.Name.str.contains("Mega")
df_clean = df_pk_one[~df_mega]
df_clean
# Out:
#        #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur     Grass   Poison    318   45      49       49       65
# 1      2     Ivysaur     Grass   Poison    405   60      62       63       80
# 2      3    Venusaur     Grass   Poison    525   80      82       83      100
# 4      4  Charmander      Fire      NaN    309   39      52       43       60
# 5      5  Charmeleon      Fire      NaN    405   58      64       58       80
# 6      6   Charizard      Fire   Flying    534   78      84       78      109
# 9      7    Squirtle     Water      NaN    314   44      48       65       50
# 10     8   Wartortle     Water      NaN    405   59      63       80       65
# 11     9   Blastoise     Water      NaN    530   79      83      100       85
# 13    10    Caterpie       Bug      NaN    195   45      30       35       20
# 14    11     Metapod       Bug      NaN    205   50      20       55       25
# ...

# %%
#Pokémon más fuertes en sus campos

def masfuerte(habilidad):
    pd.DataFrame(df_clean,columns=['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed'])
    stats = df_clean[habilidad].max()
    return stats


def pokemondestacado(habilidad):
    try:
        pokemon = masfuerte(habilidad)
        name_dataframe = df_clean[df_clean[habilidad] == pokemon]
    except KeyError:
        print ('Recuerda escribir correctamente la información')
    return name_dataframe

pokemondestacado('HP')
# Out:
#        #     Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 121  113  Chansey  Normal    NaN    450  250       5        5       35
#
#      Sp. Def  Speed  Generation  Legendary
# 121      105     50           1      False

# %%
#¿qué pokémon es X número?

import requests
from IPython.display import Image 

def getPokemon(pokeId):
    if pokeId <= 151:
        url = "https://pokeapi.co/api/v2/pokemon/{}".format(pokeId)
        response = requests.get(url)
        data = response.json()

        display(Image(data["sprites"]["front_default"]))
        display(Image(data["sprites"]["back_default"]))
        print("Este es: ",(data["name"]).upper())

        listaabilities = []
        for i in data['abilities']:
            listaabilities.append(i["ability"]['name'] )
        print ("Habilidad especial:", " & ".join(listaabilities))
            

        types=[]
        for i in data['types']:
            types.append(i['type']['name'])
        print("Es un Pokémon de tipo: "," & ".join(types))
    else:
        print("El pokémon que estás buscando no está en nuestra Pokédex de primera generación")
    
    
        
getPokemon(3)
# Out:
# Este es:  VENUSAUR
# Habilidad especial: chlorophyll & overgrow
# Es un Pokémon de tipo:  poison & grass

# %%
#construyendo la gráfica de los mejores pokémons por categoría
import matplotlib.pyplot as plt

# %%
#guardar la info: crear PDF
#renombrar columnas para evitar errores en la escritura
#valorar si puedo hacer un HandlingError cuando escribimos la habilidad del Pokemon
